# %%
from pathlib import Path # Import Path so we can work with file/folder paths easily
import pandas as pd
from datetime import datetime

# %%
data_file = Path('/content/team_1.parquet')
data = pd.read_parquet(data_file, engine='pyarrow') #engine='pyarrow' tells pandas which library to use to read parquet files

# We convert each text value into a real datetime object
data['timestamp'] = data['timestamp'].apply(lambda x: datetime.fromisoformat(x))

# Create a new column called 'year'
data['year'] = data['timestamp'].dt.year

# Create output folder
output_dir = Path('split_by_year')
output_dir.mkdir(parents=True, exist_ok=True)

# Split by year and save as CSV
for year, df_year in data.groupby('year'):
    output_path = output_dir / f'team_1_{year}.csv'
    df_year.drop(columns='year').to_csv(output_path, index=False)
    print(f"Saved {len(df_year)} rows for year {year} → {output_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_21803/1519428790.py in <cell line: 0>()
#       1 data_file = Path('/content/team_1.parquet')
# ----> 2 data = pd.read_parquet(data_file, engine='pyarrow') #engine='pyarrow' tells pandas which library to use to read parquet files
#       3
#       4 # We convert each text value into a real datetime object
#       5 data['timestamp'] = data['timestamp'].apply(lambda x: datetime.fromisoformat(x))
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     665     check_dtype_backend(dtype_backend)
#     666
# --> 667     return impl.read(
#     668         path,
#     669         columns=columns,
#
# ...

# %%
# Split by month and save as CSV
for (year, month), df_month in data.groupby(['year', 'month']):
    output_path = output_dir / f'team_1_{year}_{month:02d}.csv'
    df_month.drop(columns=['year', 'month']).to_csv(output_path, index=False)
    print(f"Saved {len(df_month)} rows for {year}-{month:02d} → {output_path}")
# Out:
# Saved 154815 rows for 2024-01 → split_by_year/team_1_2024_01.csv
# Saved 145318 rows for 2024-02 → split_by_year/team_1_2024_02.csv
# Saved 138619 rows for 2024-03 → split_by_year/team_1_2024_03.csv
# Saved 142875 rows for 2024-04 → split_by_year/team_1_2024_04.csv
# Saved 152912 rows for 2024-05 → split_by_year/team_1_2024_05.csv
# Saved 138910 rows for 2024-06 → split_by_year/team_1_2024_06.csv
# Saved 149935 rows for 2024-07 → split_by_year/team_1_2024_07.csv
# Saved 146398 rows for 2024-08 → split_by_year/team_1_2024_08.csv
# Saved 138737 rows for 2024-09 → split_by_year/team_1_2024_09.csv
# Saved 152319 rows for 2024-10 → split_by_year/team_1_2024_10.csv
# Saved 149151 rows for 2024-11 → split_by_year/team_1_2024_11.csv
# Saved 153696 rows for 2024-12 → split_by_year/team_1_2024_12.csv
# Saved 149973 rows for 2025-01 → split_by_year/team_1_2025_01.csv
# Saved 132994 rows for 2025-02 → split_by_year/team_1_2025_02.csv
# ...

# %%
df24 = pd.read_csv('/content/split_by_year/team_1_2024.csv')
df24.head()
# Out:
#   station_id  state   city               station_name  \
# 0  site_5024  Delhi  Delhi       Alipur, Delhi - DPCC
# 1   site_301  Delhi  Delhi  Anand Vihar, Delhi - DPCC
# 2  site_1420  Delhi  Delhi  Ashok Vihar, Delhi - DPCC
# 3   site_301  Delhi  Delhi  Anand Vihar, Delhi - DPCC
# 4   site_301  Delhi  Delhi  Anand Vihar, Delhi - DPCC
#
#                    timestamp                   datetime  at_c  rh_percent  \
# 0  2024-01-01 00:00:00+00:00  2024-01-01 00:00:00+00:00   8.2        76.0
# 1  2024-01-01 00:00:00+00:00  2024-01-01 00:00:00+00:00  11.5        80.0
# 2  2024-01-01 00:00:00+00:00  2024-01-01 00:00:00+00:00  10.9        83.9
# 3  2024-01-01 00:00:00+00:00  2024-01-01 00:00:00+00:00  11.5        80.0
# 4  2024-01-01 00:00:00+00:00  2024-01-01 00:00:00+00:00  11.5        80.0
#
#    ws_m_s  wd_deg  ...  tot_rf_mm  sr_w_mt2  bp_mmhg  vws_m_s  pollutant  \
# 0     NaN    72.9  ...        0.0       3.8    973.7      NaN    benzene
# ...

# %%
df25 = pd.read_csv('/content/split_by_year/team_1_2025.csv')
df25.head()
# Out:
#   station_id  state   city            station_name                  timestamp  \
# 0   site_108  Delhi  Delhi  Aya Nagar, Delhi - IMD  2025-01-01 00:00:00+00:00
# 1   site_108  Delhi  Delhi  Aya Nagar, Delhi - IMD  2025-01-01 00:00:00+00:00
# 2   site_108  Delhi  Delhi  Aya Nagar, Delhi - IMD  2025-01-01 00:00:00+00:00
# 3   site_108  Delhi  Delhi  Aya Nagar, Delhi - IMD  2025-01-01 00:00:00+00:00
# 4   site_108  Delhi  Delhi  Aya Nagar, Delhi - IMD  2025-01-01 00:00:00+00:00
#
#                     datetime  at_c  rh_percent  ws_m_s  wd_deg  ...  \
# 0  2025-01-01 00:00:00+00:00   NaN         NaN     NaN     NaN  ...
# 1  2025-01-01 00:00:00+00:00   NaN         NaN     NaN     NaN  ...
# 2  2025-01-01 00:00:00+00:00   NaN         NaN     NaN     NaN  ...
# 3  2025-01-01 00:00:00+00:00   NaN         NaN     NaN     NaN  ...
# 4  2025-01-01 00:00:00+00:00   NaN         NaN     NaN     NaN  ...
#
#    tot_rf_mm  sr_w_mt2  bp_mmhg  vws_m_s  pollutant   value  \
# ...
